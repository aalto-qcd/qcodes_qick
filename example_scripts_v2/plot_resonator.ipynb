# %%
from header_plot import *

# %%
run_id = 801
electrical_delay = -2.12e-6
ds = qc.load_by_id(run_id).to_xarray_dataset()
f = ds["QickInstrument_dac1_tone0_freq"]
iq = ds["iq"] * np.exp(2j * np.pi * f * electrical_delay)
phase = xr.apply_ufunc(np.angle, iq)
plt.figure()
abs(iq).plot()
